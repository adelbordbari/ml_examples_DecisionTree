# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""
read dataset
"""

mushroom = "mushroom.csv"
df = pd.read_csv(mushroom)
df.head()
# Out:
#   cap-shape cap-surface cap-color bruises%3F odor gill-attachment  \
# 0         x           s         n          t    p               f
# 1         x           s         y          t    a               f
# 2         b           s         w          t    l               f
# 3         x           y         w          t    p               f
# 4         x           s         g          f    n               f
#
#   gill-spacing gill-size gill-color stalk-shape  ... stalk-color-above-ring  \
# 0            c         n          k           e  ...                      w
# 1            c         b          k           e  ...                      w
# 2            c         b          n           e  ...                      w
# 3            c         n          n           e  ...                      w
# 4            w         b          k           t  ...                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# 1                      w         p          w           o         p
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         e
#
#   spore-print-color population habitat class
# 0                 k          s       u     p
# 1                 n          n       g     e
# 2                 n          n       m     e
# 3                 k          s       u     p
# 4                 n          a       g     e
#
# [5 rows x 23 columns]

# %%
#df['cap-shape'].apply(lambda x:ord(x)-64)

df[:] = df.to_numpy().astype('<U1').view(np.uint32)-64
df['class']= df['class'].map(str)
df
# Out:
#       cap-shape  cap-surface  cap-color  bruises%3F  odor  gill-attachment  \
# 0            56           51         46          52    48               38
# 1            56           51         57          52    33               38
# 2            34           51         55          52    44               38
# 3            56           57         55          52    48               38
# 4            56           51         39          38    46               38
# ...         ...          ...        ...         ...   ...              ...
# 8119         43           51         46          38    46               33
# 8120         56           51         46          38    46               33
# 8121         38           51         46          38    46               33
# 8122         43           57         46          38    57               38
# 8123         56           51         46          38    46               33
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0               35         46          43           37  ...
# 1               35         34          43           37  ...
# 2               35         34          46           37  ...
# 3               35         46          46           37  ...
# 4               55         34          43           52  ...
# ...            ...        ...         ...          ...  ...
# 8119            35         34          57           37  ...
# 8120            35         34          57           37  ...
# 8121            35         34          46           37  ...
# 8122            35         46          34           52  ...
# 8123            35         34          57           37  ...
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                         55                      55         48          55
# 1                         55                      55         48          55
# 2                         55                      55         48          55
# 3                         55                      55         48          55
# 4                         55                      55         48          55
# ...                      ...                     ...        ...         ...
# 8119                      47                      47         48          47
# 8120                      47                      47         48          46
# 8121                      47                      47         48          47
# 8122                      55                      55         48          55
# 8123                      47                      47         48          47
#
#       ring-number  ring-type  spore-print-color  population  habitat  class
# 0              47         48                 43          51       53     48
# 1              47         48                 46          46       39     37
# 2              47         48                 46          46       45     37
# 3              47         48                 43          51       53     48
# 4              47         37                 46          33       39     37
# ...           ...        ...                ...         ...      ...    ...
# 8119           47         48                 34          35       44     37
# 8120           47         48                 34          54       44     37
# 8121           47         48                 34          35       44     37
# 8122           47         37                 55          54       44     48
# 8123           47         48                 47          35       44     37
#
# [8124 rows x 23 columns]

# %%
# create train-test sets
x = df.drop(columns="class")
y = df["class"]

print(y)
x
# Out:
# 0       48
# 1       37
# 2       37
# 3       48
# 4       37
#         ..
# 8119    37
# 8120    37
# 8121    37
# 8122    48
# 8123    37
# Name: class, Length: 8124, dtype: object
#       cap-shape  cap-surface  cap-color  bruises%3F  odor  gill-attachment  \
# 0            56           51         46          52    48               38
# 1            56           51         57          52    33               38
# 2            34           51         55          52    44               38
# 3            56           57         55          52    48               38
# 4            56           51         39          38    46               38
# ...         ...          ...        ...         ...   ...              ...
# 8119         43           51         46          38    46               33
# 8120         56           51         46          38    46               33
# 8121         38           51         46          38    46               33
# 8122         43           57         46          38    57               38
# 8123         56           51         46          38    46               33
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0               35         46          43           37  ...
# 1               35         34          43           37  ...
# 2               35         34          46           37  ...
# 3               35         46          46           37  ...
# 4               55         34          43           52  ...
# ...            ...        ...         ...          ...  ...
# 8119            35         34          57           37  ...
# 8120            35         34          57           37  ...
# 8121            35         34          46           37  ...
# 8122            35         46          34           52  ...
# 8123            35         34          57           37  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                           51                      55
# 1                           51                      55
# 2                           51                      55
# 3                           51                      55
# 4                           51                      55
# ...                        ...                     ...
# 8119                        51                      47
# 8120                        51                      47
# 8121                        51                      47
# 8122                        43                      55
# 8123                        51                      47
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                         55         48          55           47         48
# 1                         55         48          55           47         48
# 2                         55         48          55           47         48
# 3                         55         48          55           47         48
# 4                         55         48          55           47         37
# ...                      ...        ...         ...          ...        ...
# 8119                      47         48          47           47         48
# 8120                      47         48          46           47         48
# 8121                      47         48          47           47         48
# 8122                      55         48          55           47         37
# 8123                      47         48          47           47         48
#
#       spore-print-color  population  habitat
# 0                    43          51       53
# 1                    46          46       39
# 2                    46          46       45
# 3                    43          51       53
# 4                    46          33       39
# ...                 ...         ...      ...
# 8119                 34          35       44
# 8120                 34          54       44
# 8121                 34          35       44
# 8122                 55          54       44
# 8123                 47          35       44
#
# [8124 rows x 22 columns]

# %%
labels = np.unique(y)
print(labels)

feature_names = x.columns
print(feature_names)
# Out:
# ['37' '48']
# Index(['cap-shape', 'cap-surface', 'cap-color', 'bruises%3F', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3)

# %%
print("train samples: ", len(x_train))
print("test samples: ", len(x_test))
# Out:
# train samples:  5686
# test samples:  2438

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
dtree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
plt.figure(figsize=(30,10))
a = tree.plot_tree(dtree, feature_names = feature_names, class_names = labels, rounded = True, filled = True, fontsize=14)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix

# %%
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(x_train, y_train)
rfc_pred = rfc.predict(x_test)
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[1269    0]
#  [   0 1169]]

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#           37       1.00      1.00      1.00      1269
#           48       1.00      1.00      1.00      1169
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438
